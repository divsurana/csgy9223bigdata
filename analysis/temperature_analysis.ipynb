# %%
# %matplotlib inline
from pandas import Series
from matplotlib import pyplot
from pandas import Series
series = Series.from_csv('/home/karan/temp.csv', header=0)
pyplot.plot(series)
pyplot.show()
